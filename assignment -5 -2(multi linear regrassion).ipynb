# %%
# Q2 50 startup data set

# %%
# importing the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
import statsmodels.api as sm
from statsmodels.graphics.regressionplots import influence_plot

# %%
# importing dataset 

data=pd.read_csv("50_Startups.csv")
data
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %% [markdown]
# # EDA Process

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
# changing the name for comfartablity

data1=data.rename({'R&D Spend':'RDS','Administration':'ADMS','Marketing Spend':'MKTS'},axis=1)
data1
# Out:
#           RDS       ADMS       MKTS       State     Profit
# 0   165349.20  136897.80  471784.10    New York  192261.83
# 1   162597.70  151377.59  443898.53  California  191792.06
# 2   153441.51  101145.55  407934.54     Florida  191050.39
# 3   144372.41  118671.85  383199.62    New York  182901.99
# 4   142107.34   91391.77  366168.42     Florida  166187.94
# 5   131876.90   99814.71  362861.36    New York  156991.12
# 6   134615.46  147198.87  127716.82  California  156122.51
# 7   130298.13  145530.06  323876.68     Florida  155752.60
# 8   120542.52  148718.95  311613.29    New York  152211.77
# 9   123334.88  108679.17  304981.62  California  149759.96
# 10  101913.08  110594.11  229160.95     Florida  146121.95
# 11  100671.96   91790.61  249744.55  California  144259.40
# 12   93863.75  127320.38  249839.44     Florida  141585.52
# 13   91992.39  135495.07  252664.93  California  134307.35
# 14  119943.24  156547.42  256512.92     Florida  132602.65
# ...

# %%
data1[data1.duplicated()]  # nno duplicated data
# Out:
# Empty DataFrame
# Columns: [RDS, ADMS, MKTS, State, Profit]
# Index: []

# %%
data1.describe()
# Out:
#                  RDS           ADMS           MKTS         Profit
# count      50.000000      50.000000      50.000000      50.000000
# mean    73721.615600  121344.639600  211025.097800  112012.639200
# std     45902.256482   28017.802755  122290.310726   40306.180338
# min         0.000000   51283.140000       0.000000   14681.400000
# 25%     39936.370000  103730.875000  129300.132500   90138.902500
# 50%     73051.080000  122699.795000  212716.240000  107978.190000
# 75%    101602.800000  144842.180000  299469.085000  139765.977500
# max    165349.200000  182645.560000  471784.100000  192261.830000

# %% [markdown]
# # correlation analysis

# %%
data1.corr()
# Out:
#              RDS      ADMS      MKTS    Profit
# RDS     1.000000  0.241955  0.724248  0.972900
# ADMS    0.241955  1.000000 -0.032154  0.200717
# MKTS    0.724248 -0.032154  1.000000  0.747766
# Profit  0.972900  0.200717  0.747766  1.000000

# %%
# ploting pairplot for better vizualizaed 

sns.set_style(style= 'darkgrid')
sns.pairplot(data1)

# %% [markdown]
# # model building

# %%
model =smf.ols("Profit~RDS+ADMS+MKTS",data=data1).fit()

# %% [markdown]
# # model Testing

# %%
# finding coeffient parameters

model.params
# Out:
# Intercept    50122.192990
# RDS              0.805715
# ADMS            -0.026816
# MKTS             0.027228
# dtype: float64

# %%
# summary for all details 
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.948
# Method:                 Least Squares   F-statistic:                     296.0
# Date:                Wed, 20 Apr 2022   Prob (F-statistic):           4.53e-30
# Time:                        11:45:16   Log-Likelihood:                -525.39
# No. Observations:                  50   AIC:                             1059.
# Df Residuals:                      46   BIC:                             1066.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   5.012e+04   6572.353      7.626      0.000    3.69e+04    6.34e+04
# ...

# %%
# SLR = SIMPLE LINEAR REGRASSION MODEL

# MLR =  MULTIPLE LINEAR REGRASSION MODEL

# %% [markdown]
# # build SLR and MLR model for insignificient variable 'ADMS' AND 'MKTS'
# #aslo finding their t value and p value

# %%
slr_a = smf.ols("Profit~ADMS",data = data1).fit()
slr_a.tvalues , slr_a.pvalues #AdMs has in significient p values
# Out:
# (Intercept    3.040044
#  ADMS         1.419493
#  dtype: float64,
#  Intercept    0.003824
#  ADMS         0.162217
#  dtype: float64)

# %%
slr_m = smf.ols("Profit~MKTS",data = data1).fit()
slr_m.tvalues,slr_m.pvalues   # MKTS has significant pvalue
# Out:
# (Intercept    7.808356
#  MKTS         7.802657
#  dtype: float64,
#  Intercept    4.294735e-10
#  MKTS         4.381073e-10
#  dtype: float64)

# %%
mlr_am = smf.ols("Profit~ADMS+MKTS", data=data1).fit()
mlr_am.tvalues , mlr_am.pvalues   #varible have significient p values
# Out:
# (Intercept    1.142741
#  ADMS         2.467779
#  MKTS         8.281039
#  dtype: float64,
#  Intercept    2.589341e-01
#  ADMS         1.729198e-02
#  MKTS         9.727245e-11
#  dtype: float64)

# %% [markdown]
# # model validation

# %%
res = model.resid
res
# Out:
# 0      -259.422890
# 1      2635.291768
# 2      8903.110904
# 3      9205.289974
# 4     -5951.574183
# 5     -6589.660571
# 6     -1991.586669
# 7     -4268.763048
# 8       470.070301
# 9     -5124.724110
# 10    10612.933633
# 11     8685.687039
# 12    12447.465818
# 13     6819.358337
# 14   -16945.996335
# 15   -16318.119985
# 16    10077.524599
# 17    -4822.077208
# 18    -4747.326806
# 19     7141.643633
# 20     1834.360769
# 21    -6006.431640
# 22    -4354.731717
# 23    -1262.625221
# 24    -4810.926113
# 25     5166.614935
# 26    -4867.035350
# 27    -9399.761457
# 28     1622.353995
# 29     -790.343452
# 30      485.217064
# 31     -204.296276
# 32    -1573.488985
# 33    -1136.087805
# 34     7673.526259
# 35     5967.910432
# 36    15422.015415
# 37      329.602292
# 38    11531.629352
# 39    -2723.251977
# 40     3423.956009
# 41     2996.273761
# 42      878.078179
# 43     9591.940037
# 44      588.975084
# 45    17275.430313
# 46    -6675.456853
# ...

# %%
res.mean()
# Out:
# 7.639755494892597e-11

# %%
# ploting Q -Q plot to cheak our error is normaly disstibuted or not

import statsmodels.api as sm
qqplot = sm.qqplot(res , line ='q')
plt.title("test for normality of residules (Q-Q plot)")
plt.show()

# %% [markdown]
# # residule plot for homoscadacity

# %%
def get_standardized_values (vals):
    return (vals - vals.mean())/vals.std()

# %%
plt.scatter(get_standardized_values(model.fittedvalues),
           get_standardized_values(model.resid))

plt.title("residual plot")
plt.xlabel("standardized fitted values")
plt.ylabel("standardized residual values")
plt.show()

# %% [markdown]
# # Residuals Vs Regressors

# %%
# Test for errors or Residuals Vs Regressors or independent 'x' variables or predictors 
# using Residual Regression Plots code graphics.plot_regress_exog(model,'x',fig)    # exo

# %%
fig= plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,"RDS",fig = fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig= plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,"ADMS",fig = fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig= plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,"MKTS",fig = fig)
plt.show()
# Out:
# eval_env: 1

# %% [markdown]
# # model deletion diagnostics (heaking outlier  or influencer )

# %%
# two techniqued are used 1} cook's distance 2} leverage value

# %%
#  cook distannce : if cooks distance >1 ,then its an outlier
# get influencer using cooks distance 

(c,_)= model.get_influence().cooks_distance
c
# Out:
# array([3.21825244e-05, 3.27591036e-03, 3.23842699e-02, 2.17206555e-02,
#        1.44833032e-02, 1.17158463e-02, 2.91766303e-03, 3.56513444e-03,
#        4.04303948e-05, 4.86758017e-03, 1.51064757e-02, 1.63564959e-02,
#        1.15516625e-02, 4.01422811e-03, 6.12934253e-02, 3.40013448e-02,
#        8.33556413e-03, 3.30534399e-03, 2.16819303e-03, 4.07440577e-02,
#        4.25137222e-04, 1.09844352e-02, 2.91768000e-03, 2.76030254e-04,
#        5.04643588e-03, 3.00074623e-03, 3.41957068e-03, 2.98396413e-02,
#        1.31590664e-03, 1.25992620e-04, 4.18505125e-05, 9.27434786e-06,
#        7.08656521e-04, 1.28122674e-04, 2.09815032e-02, 6.69508674e-03,
#        5.55314705e-02, 6.55050578e-05, 5.61547311e-02, 1.54279607e-03,
#        1.84850929e-03, 1.97578066e-03, 1.36089280e-04, 2.05553171e-02,
#        1.23156041e-04, 9.03234206e-02, 5.45303387e-02, 5.33885616e-03,
#        1.90527441e-01, 2.88082293e-01])

# %%
# plot the influencer using the stem plot 

fig = plt.figure(figsize = (20,7))
plt.stem(np.arange(len(data)),np.round(c,5))
plt.xlabel("row index")
plt.ylabel("Cooks Distance")
plt.show()

# %%
# index and value of influncer where c>0.5
np.argmax(c), np.max(c)

# %%
# 2. leverage value using high influence points : points beyond leverage _ cutpff value are influencer 
influence_plot(model)
plt.show()

# %%
# leverage cutoff value = 3*(k+1)/n ; k = no.of feature/columns & n = no of data points 


k = data1.shape[1]
n= data1.shape[0]
leverage_cutoff = (3*(k+1))/n
leverage_cutoff
# Out:
# 0.3673469387755102

# %%
data[data.index.isin([49])]
# Out:
#     R&D Spend  Administration  Marketing Spend       State   Profit
# 49        0.0        116983.8         45173.06  California  14681.4

# %% [markdown]
# # improving the model

# %%
# discard the data points which are influencer and reassign the row number (reset_index(drop=True))

data2 = data.drop(data.index[[49]],axis=0).reset_index(drop=True)
data2
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %% [markdown]
# # model deletion diagnotics and final model

# %%
model = smf.ols("Profit~RDS+ADMS+MKTS",data=data2).fit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\patsy\compat.py:36, in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#      35 try:
# ---> 36     return f(*args, **kwargs)
#      37 except Exception as e:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\patsy\eval.py:165, in EvalEnvironment.eval(self, expr, source_name, inner_namespace)
#     164 code = compile(expr, source_name, "eval", self.flags, False)
# --> 165 return eval(code, {}, VarLookupDict([inner_namespace]
#     166                                     + self._namespaces))
#
# File <string>:1, in <module>
#
# NameError: name 'ADMS' is not defined
#
# The above exception was the direct cause of the following exception:
#
# PatsyError                                Traceback (most recent call last)
# Input In [72], in <module>
# ...

# %%
data1
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
data1=data.rename({'R&D Spend':'RDS','Administration':'ADMS','Marketing Spend':'MKTS'},axis=1)
data1
# Out:
#           RDS       ADMS       MKTS       State     Profit
# 0   165349.20  136897.80  471784.10    New York  192261.83
# 1   162597.70  151377.59  443898.53  California  191792.06
# 2   153441.51  101145.55  407934.54     Florida  191050.39
# 3   144372.41  118671.85  383199.62    New York  182901.99
# 4   142107.34   91391.77  366168.42     Florida  166187.94
# 5   131876.90   99814.71  362861.36    New York  156991.12
# 6   134615.46  147198.87  127716.82  California  156122.51
# 7   130298.13  145530.06  323876.68     Florida  155752.60
# 8   120542.52  148718.95  311613.29    New York  152211.77
# 9   123334.88  108679.17  304981.62  California  149759.96
# 10  101913.08  110594.11  229160.95     Florida  146121.95
# 11  100671.96   91790.61  249744.55  California  144259.40
# 12   93863.75  127320.38  249839.44     Florida  141585.52
# 13   91992.39  135495.07  252664.93  California  134307.35
# 14  119943.24  156547.42  256512.92     Florida  132602.65
# ...

# %%
model = smf.ols("Profit~RDS+ADMS+MKTS",data=data1).fit()

# %%
while model.rsquared < 0.99:
    for c in [np.max(c)>1]:
        model=smf.ols("Profit~RDS+ADMS+MKTS",data=data1).fit()
        (c,_)=model.get_influence().cooks_distance
        c
        np.argmax(c) , np.max(c)
        data1=data1.drop(data1.index[[np.argmax(c)]],axis=0).reset_index(drop=True)
        data1
    else:
        final_model=smf.ols("Profit~RDS+ADMS+MKTS",data=data1).fit()
        final_model.rsquared , final_model.aic
        print("Thus model accuracy is improved to",final_model.rsquared)
# Out:
# Thus model accuracy is improved to 0.9613162435129847
# Thus model accuracy is improved to 0.9626766170294073
# Thus model accuracy is improved to 0.9614129113440602
# Thus model accuracy is improved to 0.962593650298269
# Thus model accuracy is improved to 0.9638487279209415
# Thus model accuracy is improved to 0.9663901957918793
# Thus model accuracy is improved to 0.9706076169779905
# Thus model accuracy is improved to 0.9727840588916423
# Thus model accuracy is improved to 0.9734292907181952
# Thus model accuracy is improved to 0.9785801571833451
# Thus model accuracy is improved to 0.9777383743090916
# Thus model accuracy is improved to 0.9790510088977512
# Thus model accuracy is improved to 0.9790004461890552
# Thus model accuracy is improved to 0.9807878666153609
# Thus model accuracy is improved to 0.9838299343609735
# Thus model accuracy is improved to 0.983114992639277
# Thus model accuracy is improved to 0.9833768520972176
# ...

# %%
final_model.rsquared
# Out:
# 0.9882757054424702

# %%
data1
# Out:
#           RDS       ADMS       MKTS       State     Profit
# 0   142107.34   91391.77  366168.42     Florida  166187.94
# 1   131876.90   99814.71  362861.36    New York  156991.12
# 2   130298.13  145530.06  323876.68     Florida  155752.60
# 3   120542.52  148718.95  311613.29    New York  152211.77
# 4   123334.88  108679.17  304981.62  California  149759.96
# 5    91992.39  135495.07  252664.93  California  134307.35
# 6    94657.16  145077.58  282574.31    New York  125370.37
# 7    91749.16  114175.79  294919.57     Florida  124266.90
# 8    76253.86  113867.30  298664.47  California  118474.03
# 9    67532.53  105751.03  304768.73     Florida  108733.99
# 10   77044.01   99281.34  140574.81    New York  108552.04
# 11   64664.71  139553.16  137962.62  California  107404.34
# 12   75328.87  144135.98  134050.07     Florida  105733.54
# 13   66051.52  182645.56  118148.20     Florida  103282.38
# 14   65605.48  153032.06  107138.38    New York  101004.64
# ...

# %% [markdown]
# # model prediction

# %%
# say new data for prediction 
new_data = pd.DataFrame({'RDS':70000,'ADMS':90000,'MKTS':140000},index=[0])
new_data
# Out:
#      RDS   ADMS    MKTS
# 0  70000  90000  140000

# %%
# manual prediction of the price 
final_model.predict(new_data)
# Out:
# 0    104858.729408
# dtype: float64

# %%
# automatic prediction of price with 90 % accuracy

pred_y = final_model.predict(data1)
pred_y
# Out:
# 0     165589.539700
# 1     158552.826483
# 2     156789.000710
# 3     149524.698853
# 4     150122.356712
# 5     126598.769555
# 6     130104.785747
# 7     127878.387928
# 8     117298.757074
# 9     111329.242429
# 10    110009.916133
# 11    102331.717613
# 12    109661.804131
# 13    103462.767086
# 14    101874.612012
# 15     97655.794577
# 16     97872.919535
# 17     96858.382686
# 18     98654.449007
# 19     93583.600868
# 20     91186.568204
# 21     88571.938968
# 22     84521.312916
# 23     78528.002935
# 24     76670.262623
# 25     73237.524757
# 26     68075.710756
# dtype: float64

# %% [markdown]
# # table contaning R^2 value for each prepared model

# %%
d2={'Prep_Models':['Model','Final_Model'],'Rsquared':[model.rsquared,final_model.rsquared]}
table=pd.DataFrame(d2)
table
# Out:
#    Prep_Models  Rsquared
# 0        Model  0.990667
# 1  Final_Model  0.988276
